# %%
"""
1.Supervised learning: dataset that is labelled to predict, linear 
regression, decision tree, support vector, vector machine, nueral networks(supervised learbning algorithm)
2. Unsupervised learning: dals with unlabelled data, clustering algorithms to grop 
data together. k_meansclustring, hierarchical, PCA(principle component analysis)
3. Reinforcement learning

"""

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

#ML regression
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
#Contol 
pd.options.display.max_columns=50
#sns.set(style="darkgrid",rc={'axe.facecolor':'#CAFIDE'})
sns.set(style="darkgrid", rc={'axes.facecolor': '#f0f0f0'})
#Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
#load/ read dataset
df = pd.read_csv('heart_disease.csv')
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
"""
summary 
cp = chest pain
trestbs = resting blood pressure
chol = cholesterol
fbs fasting blood sugar
restecg resting electrocardiology
exang = exercise 

ca number of major vessel
thal = normal, fexied"""

# %%
#show column of people with heart disease
#column target
df.target.value_counts()
# Out:
# target
# 1    526
# 0    499
# Name: count, dtype: int64

# %%
#show male and female
count_female = len(df[df.sex == 0])
count_male = len(df[df.sex == 1])
#show output
print("Percentage of female patients:{:.2f}%".format(count_female/len(df.sex)*100))
print("Percentage of female patients:{:.2f}%".format(count_male/len(df.sex)*100))
# Out:
# Percentage of female patients:30.44%
# Percentage of female patients:69.56%

# %%
df.groupby('target').mean()
# Out:
#               age       sex        cp    trestbps        chol       fbs  \
# target
# 0       56.569138  0.827655  0.482966  134.106212  251.292585  0.164329
# 1       52.408745  0.570342  1.378327  129.245247  240.979087  0.134981
#
#          restecg     thalach     exang   oldpeak     slope        ca      thal
# target
# 0       0.456914  139.130261  0.549098  1.600200  1.166333  1.158317  2.539078
# 1       0.598859  158.585551  0.134981  0.569962  1.593156  0.370722  2.119772

# %%
#Barplot showing heart disease frequency of age
pd.crosstab(df.age,df.target).plot(kind='bar', figsize=(20,6))
plt.title('Heart disease Frequency for Ages')
plt.xlabel('age')
plt.ylabel('Frequency')
plt.show()

# %%
#Data visualization  of heart Disease frequency for sex
pd.crosstab(df.sex,df.target).plot(kind='bar', figsize=(20,6), color=['#ACDDDE', '#F7D8DA'])
plt.title('Heart disease Frequency for Sex')
plt.xlabel('0 = Female, 1 = Male')
plt.legend(['Have Heart Disease', 'Does not have Heart Disease'])
plt.ylabel('Frequency')
plt.xticks(rotation=0)
plt.show()

# %%
age = df['age']
chol = df['chol']
plt.scatter(age, chol, c= df['target'], cmap ='coolwarm')
plt.title('Scatter plot for age and Cholesterol')
plt.xlabel('Age')
plt.ylabel('chol')
plt.colorbar(label='Target')
plt.show()

# %%
"""
Working with ML model Accurancy of different ML 
Create model for logistic regression
Solve problems based on classification. Create independent variable and dependent variable
Categorical prediction

"""
# read about Decision trees, logistic regression, Independent and dependent variable

# %%
#Creating a model for logistic regression
y = df.target.values
x_data = df.drop(['target'], axis=1)

# %%
#Normalize our data-> split data for training and testing
#80% training 20% testing
#Normalize the data X = (X-Xmin)/(Xmax-Xmin)
x= (x_data - np.min(x_data))/(np.max(x_data)-np.min(x_data))

# %%
#split the data #random state helps to reshuffle/ control what you want to produce
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.3, random_state=0)

# %%
#Transpose matrices
x_train = x_train.T
y_train = y_train.T
x_test = x_test.T
y_test = y_test.T
